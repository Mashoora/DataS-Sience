# %%
import requests
from bs4 import BeautifulSoup
from textblob import TextBlob

# %%
url = "https://www.amazon.in/Set-Wet-Hair-Cool-100ml/product-reviews/B00CBRIRYG"

# %%
response = requests.get(url)

# %%
# Create a BeautifulSoup object to parse the HTML content
soup = BeautifulSoup(response.content, 'html.parser')

# %%
# Find the HTML elements containing the reviews or feedback
reviews = soup.find_all('div', class_='review')

# %%
# Extract the text from the reviews
review_texts = [review.get_text() for review in reviews]

# %%
# Perform emotion mining on the extracted reviews
sentiments = []
for review_text in review_texts:
    analysis = TextBlob(review_text)
    sentiment = 'positive' if analysis.sentiment.polarity >= 0 else 'negative'
    sentiments.append(sentiment)

# %%
# Print the reviews and sentiments
for review, sentiment in zip(review_texts, sentiments):
    print(f"Review: {review}\nSentiment: {sentiment}\n")
# Out:
# Review: Amazon Customer4.0 out of 5 stars
# , good 👍
# Reviewed in India 🇮🇳 on 20 June 2023Verified Purchase
# 👍
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: M. Haribabu.3.0 out of 5 stars
# Issue of money
# Reviewed in India 🇮🇳 on 22 May 2023Verified Purchase
# Product was normal but cost is too much
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: tammana3.0 out of 5 stars
# Great for curls
# Reviewed in India 🇮🇳 on 25 April 2022Verified Purchase
# If you are a woman with curly hair, you can use this too, it will hold your curl for days. Don’t apply too much or it can weight down your hair.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: CEO OF INDIA4.0 out of 5 stars
# Incase of curly hair this is a good one at this price
# Reviewed in India 🇮🇳 on 19 April 2022Verified Purchase
# Nothing much to say
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: Av Shirisha5.0 out of 5 stars
# Recommend for curly hair
# Reviewed in India 🇮🇳 on 14 October 2020Verified Purchase
# I have been using this product for over a year now and i love it, it has great hold i really recommend this product to curly girls if you want a gel that is affordable and holds your curl pattern then trust me on this, i still use this gel.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Av Shirisha
#
# 5.0 out of 5 stars
#
#                 Recommend for curly hair
#
#
#
#
#
#
#
#                             Reviewed in India 🇮🇳 on 14 October 2020
#
#
#
#
#
#
#             I have been using this product for over a year now and i love it, it has great hold i really recommend this product to curly girls if you want a gel that is affordable and holds your curl pattern then trust me on this, i still use this gel.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
# 4 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: Anshdeep Saini5.0 out of 5 stars
# Good product☺☺☺
# Reviewed in India 🇮🇳 on 13 August 2022Verified Purchase
# 👍👍👍
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Anshdeep Saini
#
# 5.0 out of 5 stars
#
#                 Good product☺☺☺
#
#
#
#
#
#
#
#                             Reviewed in India 🇮🇳 on 13 August 2022
#
#
#
#
#
#
#             👍👍👍
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: Amazon Customer4.0 out of 5 stars
# Recommended for styling your hair
# Reviewed in India 🇮🇳 on 30 December 2020Verified Purchase
# Gave good thickness to hair for styling
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: Moni2.0 out of 5 stars
# Setwet
# Reviewed in India 🇮🇳 on 28 May 2022Verified Purchase
# No longer stay
#
# 2 people found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: Upendra Joshi5.0 out of 5 stars
# It settles your hair but yes do not apply shampoo before using the jell it wont work
# Reviewed in India 🇮🇳 on 25 May 2021Verified Purchase
# I brought 2 set wet jell.It was cool and not that sticky.But yes the hair gets dry after 3-4 hours.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Upendra Joshi
#
# 5.0 out of 5 stars
#
#                 It settles your hair but yes do not apply shampoo before using the jell it wont work
#
#
#
#
#
#
#
#                             Reviewed in India 🇮🇳 on 25 May 2021
#
#
#
#
#
#
#             I brought 2 set wet jell.It was cool and not that sticky.But yes the hair gets dry after 3-4 hours.
#
#
#
#                 Images in this review
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
#
# Review: suresh3.0 out of 5 stars
# Nice product
# Reviewed in India 🇮🇳 on 29 December 2020Verified Purchase
# Ok for light styling.
#
# One person found this helpful
#
#
#               Helpful
#
#
# Report
#
# Showing 0 comments
# There was a problem loading comments right now. Please try again later.
# Sentiment: positive
